# %% [markdown]
# # Быстрый старт в анализ данных
#
# **с помощью `Pandas` и `Scikit-learn`,**
# **а также `numpy` и `matplotlib`**
#
# - `numpy` – матричные операции
# - `matplotlib` – научная графика
# - `pandas` – таблицы (DataFrame) для анализа данных
# - `scikit-learn` – алгоритмы машинного обучения

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('./sf_crime_classification/train.csv', sep = ',', engine = 'python')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#                       Dates                Category  \
# 0       2015-05-13 23:53:00                WARRANTS
# 1       2015-05-13 23:53:00          OTHER OFFENSES
# 2       2015-05-13 23:33:00          OTHER OFFENSES
# 3       2015-05-13 23:30:00           LARCENY/THEFT
# 4       2015-05-13 23:30:00           LARCENY/THEFT
# 5       2015-05-13 23:30:00           LARCENY/THEFT
# 6       2015-05-13 23:30:00           VEHICLE THEFT
# 7       2015-05-13 23:30:00           VEHICLE THEFT
# 8       2015-05-13 23:00:00           LARCENY/THEFT
# 9       2015-05-13 23:00:00           LARCENY/THEFT
# 10      2015-05-13 22:58:00           LARCENY/THEFT
# 11      2015-05-13 22:30:00          OTHER OFFENSES
# 12      2015-05-13 22:30:00               VANDALISM
# 13      2015-05-13 22:06:00           LARCENY/THEFT
# 14      2015-05-13 22:00:00            NON-CRIMINAL
# 15      2015-05-13 22:00:00            NON-CRIMINAL
# 16      2015-05-13 22:00:00                 ROBBERY
# ...

# %%
print(data)
# Out:
#                       Dates                Category  \
# 0       2015-05-13 23:53:00                WARRANTS
# 1       2015-05-13 23:53:00          OTHER OFFENSES
# 2       2015-05-13 23:33:00          OTHER OFFENSES
# 3       2015-05-13 23:30:00           LARCENY/THEFT
# 4       2015-05-13 23:30:00           LARCENY/THEFT
# 5       2015-05-13 23:30:00           LARCENY/THEFT
# 6       2015-05-13 23:30:00           VEHICLE THEFT
# 7       2015-05-13 23:30:00           VEHICLE THEFT
# 8       2015-05-13 23:00:00           LARCENY/THEFT
# 9       2015-05-13 23:00:00           LARCENY/THEFT
# 10      2015-05-13 22:58:00           LARCENY/THEFT
# 11      2015-05-13 22:30:00          OTHER OFFENSES
# 12      2015-05-13 22:30:00               VANDALISM
# 13      2015-05-13 22:06:00           LARCENY/THEFT
# 14      2015-05-13 22:00:00            NON-CRIMINAL
# 15      2015-05-13 22:00:00            NON-CRIMINAL
# 16      2015-05-13 22:00:00                 ROBBERY
# ...

# %%
#data.columns = [u'age', u'workclass', u'fnlwgt', u'education', u'education-num',
#       u'marital-status', u'occupation', u'relationship', u'race', u'sex',
#       u'capital-gain', u'capital-loss', u'hours-per-week', u'native-country',
#       u'class']

# %%
data.head()
# Out:
#                  Dates        Category                      Descript  \
# 0  2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1  2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2  2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                    Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 1  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 2  Wednesday   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST
# 3  Wednesday   NORTHERN            NONE   1500 Block of LOMBARD ST
# 4  Wednesday       PARK            NONE  100 Block of BRODERICK ST
#
#             X          Y
# 0 -122.425892  37.774599
# 1 -122.425892  37.774599
# 2 -122.424363  37.800414
# 3 -122.426995  37.800873
# ...

# %%
data.tail()
# Out:
#                       Dates                Category  \
# 878044  2003-01-06 00:15:00                 ROBBERY
# 878045  2003-01-06 00:01:00           LARCENY/THEFT
# 878046  2003-01-06 00:01:00           LARCENY/THEFT
# 878047  2003-01-06 00:01:00               VANDALISM
# 878048  2003-01-06 00:01:00  FORGERY/COUNTERFEITING
#
#                                          Descript DayOfWeek PdDistrict  \
# 878044           ROBBERY ON THE STREET WITH A GUN    Monday    TARAVAL
# 878045               GRAND THEFT FROM LOCKED AUTO    Monday  INGLESIDE
# 878046               GRAND THEFT FROM LOCKED AUTO    Monday   SOUTHERN
# 878047  MALICIOUS MISCHIEF, VANDALISM OF VEHICLES    Monday   SOUTHERN
# 878048                   CHECKS, FORGERY (FELONY)    Monday    BAYVIEW
#
#        Resolution                     Address           X          Y
# 878044       NONE  FARALLONES ST / CAPITOL AV -122.459033  37.714056
# 878045       NONE        600 Block of EDNA ST -122.447364  37.731948
# ...

# %% [markdown]
#  - `age` – The age of the individual
#  - `workclass` – The type of employer the individual has. Whether they are `government`, `military`, `private`, and so on.
#  - `fnlwgt` – The # of people the census takers believe that observation represents (final weight)
#  - `education` – The highest level of education achieved for that individual
#  - `education_num` – Highest level of education in numerical form
#  - `marital-status` – Marital status of the individual
#  - `occupation` – The occupation of the individual
#  - `relationship` – Contains family relationship values like husband, father, and so on, but only contains one per observation.
#  - `race` – Descriptions of the individuals race. `Black`, `White`, and so on
#  - `sex` – Biological Sex
#  - `capital_gain` – Capital gains recorded (income from investment sources, apart from wages/salary)
#  - `capital_loss` – Capital losses recorded (losses from investment sources, apart from wages/salary)
#  - `hours_per_week` – Hours worked per week
#  - `native-country` – Country of origin for person
#  - `class` – Whether or not the person makes more than \$50,000 per annum income.
#
# Extraction was done by Barry Becker from the 1994 Census database. A set of reasonably clean records was extracted using the following conditions: ((AAGE>16) && (AGI>100) && (AFNLWGT>1)&& (HRSWK>0))
#
# Prediction task is to determine whether a person makes over 50K a year.

# %%
print(data.shape)
print(data.columns)
# Out:
# (878049, 9)
# Index(['Dates', 'Category', 'Descript', 'DayOfWeek', 'PdDistrict',
#        'Resolution', 'Address', 'X', 'Y'],
#       dtype='object')

# %%
#data.columns = []

# %%
data.index
# Out:
# RangeIndex(start=0, stop=878049, step=1)

# %%
data.at[2, 'Address']
# Out:
# 'VANNESS AV / GREENWICH ST'

# %%
data['DayOfWeek'].tail()
# Out:
# 878044    Monday
# 878045    Monday
# 878046    Monday
# 878047    Monday
# 878048    Monday
# Name: DayOfWeek, dtype: object

# %%
data['DayOfWeek'][878044]
# Out:
# 'Monday'

# %%
data['DayOfWeek'].dtype.name
# Out:
# 'object'

# %%
type(data['DayOfWeek'][3])
# Out:
# str

# %%
type(data['X'])
# Out:
# pandas.core.series.Series

# %%
# How does this work? What do we pass to the operator[]?
data[['PdDistrict', 'Category']].head()
# Out:
#   PdDistrict        Category
# 0   NORTHERN        WARRANTS
# 1   NORTHERN  OTHER OFFENSES
# 2   NORTHERN  OTHER OFFENSES
# 3   NORTHERN   LARCENY/THEFT
# 4       PARK   LARCENY/THEFT

# %%
#data.index = xrange(32561)
#data.index

# %%
data.describe()
# Out:
#                    X              Y
# count  878049.000000  878049.000000
# mean     -122.422616      37.771020
# std         0.030354       0.456893
# min      -122.513642      37.707879
# 25%      -122.432952      37.752427
# 50%      -122.416420      37.775421
# 75%      -122.406959      37.784369
# max      -120.500000      90.000000

# %%
from pandas.plotting import scatter_matrix
# BE AWARE: works very slow. 
scatter_matrix(data, alpha = 0.05, figsize = (10,10))
pass

# %%
data.corr()
# Out:
#           X         Y
# X  1.000000  0.559338
# Y  0.559338  1.000000

# %%
plt.plot(data['X'], data['Y'], 'o', alpha = 0.05)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('X vs Y')
pass

# %%
data['Category'] == 'ROBBERY'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16         True
# 17        False
# 18        False
# 19        False
# 20        False
# 21         True
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 878019    False
# 878020    False
# 878021    False
# 878022    False
# 878023    False
# 878024    False
# 878025    False
# 878026    False
# 878027    False
# 878028    False
# 878029    False
# 878030    False
# 878031    False
# 878032    False
# 878033    False
# 878034    False
# 878035    False
# 878036    False
# 878037    False
# 878038    False
# 878039    False
# 878040    False
# 878041    False
# 878042    False
# ...

# %%
plt.figure(figsize = (15, 7))

plt.scatter(data[data['Category'] == 'SEX OFFENSES FORCIBLE']['PdDistrict'],
            data[data['Category'] == 'SEX OFFENSES FORCIBLE']['DayOfWeek'],
            alpha = 0.15,
            label = 'SEX OFFENSES FORCIBLE',
            color = 'r')

plt.scatter(data[data['Category'] == 'SEX OFFENSES NON FORCIBLE']['PdDistrict'],
            data[data['Category'] == 'SEX OFFENSES NON FORCIBLE']['DayOfWeek'],
            alpha = 0.45,
            label = 'SEX OFFENSES NON FORCIBLE',
            color = 'b')

plt.xlabel('PdDistrict')
# plt.xticks(range(18))
# plt.xlim(0, 17)
plt.ylabel('DayOfWeek')
# plt.legend()
# plt.grid()
# Out:
# Text(0,0.5,'DayOfWeek')

# %%
plt.figure(figsize = (20, 40))

for name in data['PdDistrict'].unique():
    plt.scatter(data[data['PdDistrict'] == name]['Resolution'],
                data[data['PdDistrict'] == name]['Category'],
                alpha = 0.1,
                label = name,
                color = 'r')

plt.xticks(range(17))
plt.yticks(range(39))
plt.xlabel('Resolution')
plt.ylabel('Category')
plt.legend()
pass

# %%
plt.figure(figsize = (15, 7))

plt.scatter(data[data['Category'] == 'SEX OFFENSES FORCIBLE']['PdDistrict'],
            data[data['Category'] == 'SEX OFFENSES FORCIBLE']['Resolution'],
            alpha = 0.15,
            label = 'SEX OFFENSES FORCIBLE',
            color = 'r')

plt.scatter(data[data['Category'] == 'SEX OFFENSES NON FORCIBLE']['PdDistrict'],
            data[data['Category'] == 'SEX OFFENSES NON FORCIBLE']['Resolution'],
            alpha = 0.15,
            label = 'SEX OFFENSES NON FORCIBLE',
            color = 'b')

plt.xlabel('PdDistrict')
plt.ylabel('DayOfWeek')
plt.legend()
pass

# %%
data.describe(include = ['object'])
# Out:
#                       Dates       Category                      Descript  \
# count                878049         878049                        878049
# unique               389257             39                           879
# top     2011-01-01 00:01:00  LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# freq                    185         174900                         60022
#
#        DayOfWeek PdDistrict Resolution                 Address
# count     878049     878049     878049                  878049
# unique         7         10         17                   23228
# top       Friday   SOUTHERN       NONE  800 Block of BRYANT ST
# freq      133734     157182     526790                   26533

# %%
data.describe(include = 'all')
# Out:
#                       Dates       Category                      Descript  \
# count                878049         878049                        878049
# unique               389257             39                           879
# top     2011-01-01 00:01:00  LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# freq                    185         174900                         60022
# mean                    NaN            NaN                           NaN
# std                     NaN            NaN                           NaN
# min                     NaN            NaN                           NaN
# 25%                     NaN            NaN                           NaN
# 50%                     NaN            NaN                           NaN
# 75%                     NaN            NaN                           NaN
# max                     NaN            NaN                           NaN
#
#        DayOfWeek PdDistrict Resolution                 Address              X  \
# ...

# %%
data['Category'].unique()
# Out:
# array(['WARRANTS', 'OTHER OFFENSES', 'LARCENY/THEFT', 'VEHICLE THEFT',
#        'VANDALISM', 'NON-CRIMINAL', 'ROBBERY', 'ASSAULT', 'WEAPON LAWS',
#        'BURGLARY', 'SUSPICIOUS OCC', 'DRUNKENNESS',
#        'FORGERY/COUNTERFEITING', 'DRUG/NARCOTIC', 'STOLEN PROPERTY',
#        'SECONDARY CODES', 'TRESPASS', 'MISSING PERSON', 'FRAUD',
#        'KIDNAPPING', 'RUNAWAY', 'DRIVING UNDER THE INFLUENCE',
#        'SEX OFFENSES FORCIBLE', 'PROSTITUTION', 'DISORDERLY CONDUCT',
#        'ARSON', 'FAMILY OFFENSES', 'LIQUOR LAWS', 'BRIBERY',
#        'EMBEZZLEMENT', 'SUICIDE', 'LOITERING',
#        'SEX OFFENSES NON FORCIBLE', 'EXTORTION', 'GAMBLING', 'BAD CHECKS',
#        'TREA', 'RECOVERED VEHICLE', 'PORNOGRAPHY/OBSCENE MAT'],
#       dtype=object)

# %%
data['Resolution'].unique()
# Out:
# array(['ARREST, BOOKED', 'NONE', 'ARREST, CITED', 'PSYCHOPATHIC CASE',
#        'JUVENILE BOOKED', 'UNFOUNDED', 'EXCEPTIONAL CLEARANCE', 'LOCATED',
#        'CLEARED-CONTACT JUVENILE FOR MORE INFO', 'NOT PROSECUTED',
#        'JUVENILE DIVERTED', 'COMPLAINANT REFUSES TO PROSECUTE',
#        'JUVENILE ADMONISHED', 'JUVENILE CITED',
#        'DISTRICT ATTORNEY REFUSES TO PROSECUTE',
#        'PROSECUTED BY OUTSIDE AGENCY', 'PROSECUTED FOR LESSER OFFENSE'],
#       dtype=object)

# %%
for name in data['Category'].unique():
    # iloc??? what is it? Is it index of the match?
    print(name, "--->", data['Resolution'][data['Category'] == name].iloc[1])
# Out:
# WARRANTS ---> NONE
# OTHER OFFENSES ---> ARREST, BOOKED
# LARCENY/THEFT ---> NONE
# VEHICLE THEFT ---> NONE
# VANDALISM ---> NONE
# NON-CRIMINAL ---> NONE
# ROBBERY ---> NONE
# ASSAULT ---> NONE
# WEAPON LAWS ---> NONE
# BURGLARY ---> NONE
# SUSPICIOUS OCC ---> NONE
# DRUNKENNESS ---> ARREST, BOOKED
# FORGERY/COUNTERFEITING ---> ARREST, BOOKED
# DRUG/NARCOTIC ---> ARREST, BOOKED
# STOLEN PROPERTY ---> ARREST, BOOKED
# SECONDARY CODES ---> JUVENILE BOOKED
# TRESPASS ---> ARREST, BOOKED
# MISSING PERSON ---> NONE
# FRAUD ---> NONE
# KIDNAPPING ---> NONE
# RUNAWAY ---> NONE
# DRIVING UNDER THE INFLUENCE ---> ARREST, BOOKED
# SEX OFFENSES FORCIBLE ---> ARREST, BOOKED
# PROSTITUTION ---> NONE
# DISORDERLY CONDUCT ---> NONE
# ARSON ---> ARREST, BOOKED
# FAMILY OFFENSES ---> ARREST, BOOKED
# LIQUOR LAWS ---> ARREST, BOOKED
# BRIBERY ---> ARREST, BOOKED
# EMBEZZLEMENT ---> NONE
# SUICIDE ---> NONE
# LOITERING ---> ARREST, BOOKED
# SEX OFFENSES NON FORCIBLE ---> NONE
# EXTORTION ---> NONE
# ...

# %%
data['PdDistrict'].unique()
# Out:
# array(['NORTHERN', 'PARK', 'INGLESIDE', 'BAYVIEW', 'RICHMOND', 'CENTRAL',
#        'TARAVAL', 'TENDERLOIN', 'MISSION', 'SOUTHERN'], dtype=object)

# %% [markdown]
# ## Задача
#
# С `capital-gain` и `capital-loss` задача кажется слишком простой
#
# `education-num` и `education` "совпадают"

# %%
# data = data.drop('capital-gain', axis = 1)\
#             .drop('capital-loss', axis = 1)\
#            .drop('education',    axis = 1)\
#            .drop('native-country', axis = 1).drop('fnlwgt', axis = 1)

# %%
data.drop(['Descript','Resolution'], axis = 1) # так тоже работает
# Out:
#                       Dates                Category  DayOfWeek  PdDistrict  \
# 0       2015-05-13 23:53:00                WARRANTS  Wednesday    NORTHERN
# 1       2015-05-13 23:53:00          OTHER OFFENSES  Wednesday    NORTHERN
# 2       2015-05-13 23:33:00          OTHER OFFENSES  Wednesday    NORTHERN
# 3       2015-05-13 23:30:00           LARCENY/THEFT  Wednesday    NORTHERN
# 4       2015-05-13 23:30:00           LARCENY/THEFT  Wednesday        PARK
# 5       2015-05-13 23:30:00           LARCENY/THEFT  Wednesday   INGLESIDE
# 6       2015-05-13 23:30:00           VEHICLE THEFT  Wednesday   INGLESIDE
# 7       2015-05-13 23:30:00           VEHICLE THEFT  Wednesday     BAYVIEW
# 8       2015-05-13 23:00:00           LARCENY/THEFT  Wednesday    RICHMOND
# 9       2015-05-13 23:00:00           LARCENY/THEFT  Wednesday     CENTRAL
# 10      2015-05-13 22:58:00           LARCENY/THEFT  Wednesday     CENTRAL
# ...

# %% [markdown]
# # Готовим данные

# %%
data['Category'].dtype.name
# Out:
# 'object'

# %%
data['X'].dtype.name
# Out:
# 'float64'

# %%
#categorical_columns = []
#numerical_columns = []
#for c in data.columns:
#    if data[c].dtype.name == 'object':
#        categorical_columns.append(c)
#    else:
#        numerical_columns.append(c)

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# ['Dates', 'Category', 'Descript', 'DayOfWeek', 'PdDistrict', 'Resolution', 'Address']
# ['X', 'Y']

# %%
for c in categorical_columns:
    print(c, data[c].unique())
# Out:
# Dates ['2015-05-13 23:53:00' '2015-05-13 23:33:00' '2015-05-13 23:30:00' ...
#  '2003-01-06 00:20:00' '2003-01-06 00:15:00' '2003-01-06 00:01:00']
# Category ['WARRANTS' 'OTHER OFFENSES' 'LARCENY/THEFT' 'VEHICLE THEFT' 'VANDALISM'
#  'NON-CRIMINAL' 'ROBBERY' 'ASSAULT' 'WEAPON LAWS' 'BURGLARY'
#  'SUSPICIOUS OCC' 'DRUNKENNESS' 'FORGERY/COUNTERFEITING' 'DRUG/NARCOTIC'
#  'STOLEN PROPERTY' 'SECONDARY CODES' 'TRESPASS' 'MISSING PERSON' 'FRAUD'
#  'KIDNAPPING' 'RUNAWAY' 'DRIVING UNDER THE INFLUENCE'
#  'SEX OFFENSES FORCIBLE' 'PROSTITUTION' 'DISORDERLY CONDUCT' 'ARSON'
#  'FAMILY OFFENSES' 'LIQUOR LAWS' 'BRIBERY' 'EMBEZZLEMENT' 'SUICIDE'
#  'LOITERING' 'SEX OFFENSES NON FORCIBLE' 'EXTORTION' 'GAMBLING'
#  'BAD CHECKS' 'TREA' 'RECOVERED VEHICLE' 'PORNOGRAPHY/OBSCENE MAT']
# Descript ['WARRANT ARREST' 'TRAFFIC VIOLATION ARREST'
#  'GRAND THEFT FROM LOCKED AUTO' 'GRAND THEFT FROM UNLOCKED AUTO'
#  'STOLEN AUTOMOBILE' 'PETTY THEFT FROM LOCKED AUTO'
# ...

# %% [markdown]
# ## Обрабатываем пропущенные значения
#
# Если данные содержат пропущенные значения, то имеется две простые альтернативы:
# - удалить столбцы с такими значениями (`data = data.dropna(axis = 1)`),
# - удалить строки с такими значениями (`data = data.dropna(axis = 0)`).
#
# После этого данных может стать совсем мало.
#
# Куда более эффективным (и в то же время по-прежнему простым) методом обычно является заполнение пропущенных значений для каждой количественной переменной их средним или медианным значением.
# Для категориальных признаков пропущенные значения можно заполнить самым популярным значением в столбце.

# %%
data.median(axis = 0)
# Out:
# X   -122.416420
# Y     37.775421
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
data[numerical_columns].count(axis = 0)
# Out:
# X    878049
# Y    878049
# dtype: int64

# %%
data[categorical_columns].count(axis = 0)
# Out:
# Dates         878049
# Category      878049
# Descript      878049
# DayOfWeek     878049
# PdDistrict    878049
# Resolution    878049
# Address       878049
# dtype: int64

# %%
data['Category'].describe()
# Out:
# count            878049
# unique               39
# top       LARCENY/THEFT
# freq             174900
# Name: Category, dtype: object

# %%
type(data['Category'].describe())
# Out:
# pandas.core.series.Series

# %%
data['Category'].describe().top
# Out:
# 'LARCENY/THEFT'

# %%
# useless because we don't have NA (see data[categorical_columns].count(axis = 0))
data['Category'] = data['Category'].fillna('LARCENY/THEFT')

# %%
data.describe(include = [object])
# Out:
#                       Dates       Category                      Descript  \
# count                878049         878049                        878049
# unique               389257             39                           879
# top     2011-01-01 00:01:00  LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# freq                    185         174900                         60022
#
#        DayOfWeek PdDistrict Resolution                 Address
# count     878049     878049     878049                  878049
# unique         7         10         17                   23228
# top       Friday   SOUTHERN       NONE  800 Block of BRYANT ST
# freq      133734     157182     526790                   26533

# %%
data_describe = data.describe(include = [object])
for c in categorical_columns:
    data[c] = data[c].fillna(data_describe[c]['top'])

# %%
data.describe(include = [object])
# Out:
#                       Dates       Category                      Descript  \
# count                878049         878049                        878049
# unique               389257             39                           879
# top     2011-01-01 00:01:00  LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# freq                    185         174900                         60022
#
#        DayOfWeek PdDistrict Resolution                 Address
# count     878049     878049     878049                  878049
# unique         7         10         17                   23228
# top       Friday   SOUTHERN       NONE  800 Block of BRYANT ST
# freq      133734     157182     526790                   26533

# %% [markdown]
# ## Векторизация
#
# Нужно что-то сделать с категориальными (номинальными) признаками

# %%
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
print(binary_columns, nonbinary_columns)
# Out:
# [] ['Dates', 'Category', 'Descript', 'DayOfWeek', 'PdDistrict', 'Resolution', 'Address']

# %%
# data['sex'].unique()

# %%
# data.at[data['sex'] == 'Male', 'sex'] = 0
# data.at[data['sex'] == 'Female', 'sex'] = 1
# data['sex'].describe()

# %% [markdown]
# К небинарными признакам применим метод _векторизации_,
# который заключается в следующем.
#
# Признак `j`, принимающий `s` значений, заменим на `s` признаков, принимащих значения `0` или `1`,
# в зависимости от того, чему равно значение исходного признака `j`.
#
# Например, в нашей задаче признак `race` принимает 5 различных значений:

# %%
data['Dates'].unique()
# Out:
# array(['2015-05-13 23:53:00', '2015-05-13 23:33:00',
#        '2015-05-13 23:30:00', ..., '2003-01-06 00:20:00',
#        '2003-01-06 00:15:00', '2003-01-06 00:01:00'], dtype=object)

# %% [markdown]
# Заменим признак `race` 5 признаками: `race_White`, `race_Black`, ..., `race_Other`.
#
#  - Если признак `race` принимает значение `White`, то признак `race_White` равен `1`, а все остальные равны `0`.
#  - Если признак `race` принимает значение `Black`, то признак `race_Black` равен `1`, а все остальные равны `0`.
#  - и т.д.
#
# Такую векторизацию осуществляет в pandas метод `get_dummies`:

# %%
# IDK what to do with vectorization of such large nonbinary things like Address and Dates
data_nonbinary = pd.get_dummies(data[['PdDistrict', 'DayOfWeek', 'Resolution', 'Descript']])
print(data_nonbinary.columns)
# Out:
# Index(['PdDistrict_BAYVIEW', 'PdDistrict_CENTRAL', 'PdDistrict_INGLESIDE',
#        'PdDistrict_MISSION', 'PdDistrict_NORTHERN', 'PdDistrict_PARK',
#        'PdDistrict_RICHMOND', 'PdDistrict_SOUTHERN', 'PdDistrict_TARAVAL',
#        'PdDistrict_TENDERLOIN',
#        ...
#        'Descript_WEAPON, DEADLY, CARRYING WITH INTENT TO COMMIT ASSAULT',
#        'Descript_WEAPON, DEADLY, EXHIBITING TO RESIST ARREST',
#        'Descript_WEAPON, POSSESS OR BRING OTHER ON SCHOOL GROUNDS',
#        'Descript_WEAPON, POSSESSING IN PUBLIC BUILDING OR OPEN MEETING',
#        'Descript_WEAPON, TAKING OR ATTEMPTING TO TAKE FROM PEACE OFFICER',
#        'Descript_WEAPONS POSSESSION BY JUVENILE SUSPECT',
#        'Descript_WEARING MASK OR DISGUISE FOR UNLAWFUL PURPOSE',
#        'Descript_WEARING THE APPAREL OF OPPOSITE SEX TO DECEIVE',
#        'Descript_WILLFUL CRUELTY TO CHILD', 'Descript_YOUTH COURT'],
#       dtype='object', length=913)

# %% [markdown]
# ## Нормализация количественных признаков
#
# Многие алгоритмы машинного обучения чувствительны к масштабированию данных.
# К таким алгоритмам, например, относится метод ближайших соседей, машина опорных векторов и др.
#
# В этом случае количественные признаки полезно _нормализовать_.
# Это можно делать разными способами.
# Например, каждый количественный признак приведем к нулевому среднему и единичному среднеквадратичному отклонению:

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#                    X              Y
# count  878049.000000  878049.000000
# mean     -122.422616      37.771020
# std         0.030354       0.456893
# min      -122.513642      37.707879
# 25%      -122.432952      37.752427
# 50%      -122.416420      37.775421
# 75%      -122.406959      37.784369
# max      -120.500000      90.000000

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)

# %%
data_numerical.describe()
# Out:
#                   X             Y
# count  8.780490e+05  8.780490e+05
# mean  -1.151137e-09  1.115529e-11
# std    1.000000e+00  1.000000e+00
# min   -2.998838e+00 -1.381970e-01
# 25%   -3.404910e-01 -4.069425e-02
# 50%    2.041549e-01  9.631156e-03
# 75%    5.158460e-01  2.921522e-02
# max    6.334059e+01  1.143133e+02

# %% [markdown]
# ## Соединяем все в одну таблицу

# %%
y = data['Category']
data = pd.concat((data_numerical, data_nonbinary, data[binary_columns]), axis = 1)
print(data.shape)
# Out:
# (878049, 915)

# %%
data.describe()
# Out:
#                   X             Y  PdDistrict_BAYVIEW  PdDistrict_CENTRAL  \
# count  8.780490e+05  8.780490e+05       878049.000000       878049.000000
# mean  -1.151137e-09  1.115529e-11            0.101852            0.097329
# std    1.000000e+00  1.000000e+00            0.302454            0.296406
# min   -2.998838e+00 -1.381970e-01            0.000000            0.000000
# 25%   -3.404910e-01 -4.069425e-02            0.000000            0.000000
# 50%    2.041549e-01  9.631156e-03            0.000000            0.000000
# 75%    5.158460e-01  2.921522e-02            0.000000            0.000000
# max    6.334059e+01  1.143133e+02            1.000000            1.000000
#
#        PdDistrict_INGLESIDE  PdDistrict_MISSION  PdDistrict_NORTHERN  \
# count         878049.000000       878049.000000        878049.000000
# mean               0.089796            0.136562             0.119920
# std                0.285889            0.343384             0.324869
# ...

# %% [markdown]
# # X и y

# %%
# X = data.drop(('Category'), axis = 1) # выбрасываем столбец 'class' - в нашем случае уже все сделано
# y = data['Category']
X = data
feature_names = data.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['X', 'Y', 'PdDistrict_BAYVIEW', 'PdDistrict_CENTRAL',
#        'PdDistrict_INGLESIDE', 'PdDistrict_MISSION', 'PdDistrict_NORTHERN',
#        'PdDistrict_PARK', 'PdDistrict_RICHMOND', 'PdDistrict_SOUTHERN',
#        ...
#        'Descript_WEAPON, DEADLY, CARRYING WITH INTENT TO COMMIT ASSAULT',
#        'Descript_WEAPON, DEADLY, EXHIBITING TO RESIST ARREST',
#        'Descript_WEAPON, POSSESS OR BRING OTHER ON SCHOOL GROUNDS',
#        'Descript_WEAPON, POSSESSING IN PUBLIC BUILDING OR OPEN MEETING',
#        'Descript_WEAPON, TAKING OR ATTEMPTING TO TAKE FROM PEACE OFFICER',
#        'Descript_WEAPONS POSSESSION BY JUVENILE SUSPECT',
#        'Descript_WEARING MASK OR DISGUISE FOR UNLAWFUL PURPOSE',
#        'Descript_WEARING THE APPAREL OF OPPOSITE SEX TO DECEIVE',
#        'Descript_WILLFUL CRUELTY TO CHILD', 'Descript_YOUTH COURT'],
#       dtype='object', length=915)

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (878049, 915)
# (878049,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 614634 263415

# %%
22792+9769
# Out:
# 32561

# %%
#data_drop = data.drop('capital-gain',   axis = 1)\
#                .drop('capital-loss',   axis = 1)\
#                .drop('education',      axis = 1)\
#                .drop('fnlwgt',         axis = 1)\
#                .drop('workclass',      axis = 1)\
#                .drop('race',           axis = 1)\
#                .drop('sex',            axis = 1)\
#                .drop('native-country', axis = 1)\
#                .drop('class',          axis = 1)

# %% [markdown]
# В библиотеке scikit-learn реализована масса алгоритмов машинного обучения.
#
# #### Некоторые алгоритмы машинного обучения, реализованные в scikit-learn:
#
#  Метод                                     |  Класс
# -------------------------------------------|--------------------------------------------
#  kNN – $k$ ближайших соседей               | `sklearn.neighbors.KNeighborsClassifier`
#  LDA – линейный дискриминантный анализ     | `sklearn.discriminant_analysis.LinearDiscriminantAnalysis`
#  QDA – квадратичный дискриминантный анализ | `sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis`
#  Logistic – логистическая регрессия        | `sklearn.linear_model.LogisticRegression`
#  SVC – машина опорных векторов             | `sklearn.svm.SVC`
#  Tree – деревья решений                    | `sklearn.tree.DecisionTreeClassifier`
#  RF – случайный лес                        | `sklearn.ensemble.RandomForestClassifier`
#  ExtrRF – экстремально случайный лес       | ` `
#  AdaBoost – алгоритм AdaBoost              | `sklearn.ensemble.AdaBoostClassifier`
#  GBT – градиентный бустинг деревьев решений| `sklearn.ensemble.GradientBoostingClassifier`
#  Нейронные сети                            | ` `
#
#
#
#
# #### Основные методы классов, реализующих алгоритмы машинного обучения
# Все алгоритмы выполнены в виде классов, обладающих по крайней мере следующими методами:
#
#
#
#    Метод класса            |  Описание
#  --------------------------|-------------------------------------------------------------
#   `fit(X_train, y_train)`              |  обучение (тренировка) модели на обучающей выборке `X_train`, `y_train`
#   `predict(X)`             |  предсказание на данных `X`
#   `set_params(**params)`   |  установка параметров алгоритма
#   `get_params()`           |  чтение параметров алгоритма
#
#  Заметим, что параметры алгоритмов обучения можно задавать как в конструкторе класса, так и с помощью метода `set_params(**params)`.
#
#  #### Таблица наличия/отсутствия методов для основных алгоритмов машинного обучения:
#
#
#    Методы класса               | kNN | LDA | QDA | Logistic | SVC | Tree | RF | AdaBoost | GBT
#  ------------------------------|-----|-----|-----|----------|-----|------|----|----------|------
#   `fit(X, y)`                  |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +
#   `predict(X)`                 |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +
#   `predict_proba(X)`           |  +  |  +  |  +  |    +     |     |  +   | +  |    +     |  +
#   `predict_log_proba(X)`       |     |  +  |  +  |    +     |     |  +   | +  |    +     |  +
#   `score(X, y)`                |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +
#   `decision_function(X)`       |     |  +  |  +  |    +     |  +  |      |    |    +     |  +
#   `transform(X)`               |     |  +  |     |    +     |     |  +   | +  |          |  +
#   `staged_decision_function(X)`|     |     |     |          |     |      |    |    +     |  +
#   `staged_predict(X)`          |     |     |     |          |     |      |    |    +     |  +
#   `staged_predict_proba(X)`    |     |     |     |          |     |      |    |    +     |  +
#   `staged_score(X, y)`         |     |     |     |          |     |      |    |    +     |  +
#   `set_params(**params)`       |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +
#   `get_params()`               |  +  |  +  |  +  |    +     |  +  |  +   | +  |    +     |  +

# %% [markdown]
# # $k$NN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 10)
#knn.set_params(n_neighbors=10)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#            weights='uniform')

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#            weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.04607782843122899 0.06260843156236356

# %%
err_test = 1 - knn.score(X_test, y_test) # Другой способ

# %%
err_test
# Out:
# 0.06260843156236362

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[  258    24     0 ...    16    11     1]
#  [    0 22203     0 ...    32    65     3]
#  [    0     9    50 ...     4     0     0]
#  ...
#  [    0    52     0 ... 15315    28     0]
#  [    0    44     0 ...     7 12338     0]
#  [    0   229     0 ...    30    84  1499]]

# %%
confusion_matrix([0,1,0,1,0], [0,1,0,0,0])
# Out:
# array([[3, 0],
#        [1, 1]], dtype=int64)

# %% [markdown]
# ### Подбор параметров

# %%
# Долго!
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.167076167076 35

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.158081783082 0.161940833248

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)

err_train = np.mean(y_train != svc.predict(X_train))
err_test  = np.mean(y_test  != svc.predict(X_test))

print(err_train, err_test)
# Out:
# 0.164531414531 0.157641519091

# %% [markdown]
# ### Подбор параметров

# %%
from sklearn.grid_search import GridSearchCV
Cs = 10.**np.arange(-5, 5)
gamma_array = 10.**np.arange(-5, 5)
svc = SVC()
grid = GridSearchCV(svc, param_grid = {'C': Cs, 'gamma': gamma_array})
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_C = grid.best_estimator_.C
print(best_cv_err, best_C)
# Out:
# KeyboardInterrupt

# %%
svc = SVC(C = best_C).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)

# %% [markdown]
# # Random Forest

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 4.3875043875e-05 0.167673252124

# %% [markdown]
# ### Значимость признаков

# %%
a=[1,2,5,70,32,3,4,7,234, 3]
a[-1:3:-1]
# Out:
# [3, 234, 7, 4, 3, 32]

# %%
np.sum(rf.feature_importances_)
# Out:
# 0.99999999999999967

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
#  1. feature 'fnlwgt' (0.206736)
#  2. feature '  age' (0.183969)
#  3. feature 'education-num' (0.135674)
#  4. feature 'hours-per-week' (0.100523)
#  5. feature 'marital-status_Married-civ-spouse' (0.071025)
#  6. feature 'relationship_Husband' (0.047541)
#  7. feature 'marital-status_Never-married' (0.024367)
#  8. feature 'occupation_Exec-managerial' (0.021841)
#  9. feature '  sex' (0.013883)
# 10. feature 'occupation_Prof-specialty' (0.012760)
# 11. feature 'workclass_Private' (0.011500)
# 12. feature 'relationship_Not-in-family' (0.011351)
# 13. feature 'relationship_Wife' (0.010969)
# 14. feature 'occupation_Other-service' (0.009693)
# 15. feature 'workclass_Self-emp-not-inc' (0.009357)
# 16. feature 'relationship_Own-child' (0.009145)
# 17. feature 'workclass_Self-emp-inc' (0.007903)
# 18. feature 'race_White' (0.007806)
# 19. feature 'occupation_Sales' (0.007469)
# 20. feature 'marital-status_Divorced' (0.007117)
# ...

# %%
feature_names[[1,0,1]]
# Out:
# Index(['fnlwgt', 'age', 'fnlwgt'], dtype='object')

# %%
d_first = 20
plt.title("Feature importances")
plt.bar(range(d_first), importances[indices[:d_first]], align = 'center', color = 'r')
plt.xticks(range(d_first), feature_names[indices[:d_first]], rotation = 90)
plt.xlim([-1, d_first])
# Out:
# (-1, 20)

# %% [markdown]
# Использование только признаков
# `age`, `hourse-per-week`, `education-num`, `marital-status`, `relationship`, `occupation`
# существенно улучшает точность (понижает ошибку до 16-19%) на алгоритмах kNN и SVC.
# На самом деле, решающую роль играет удаление признака `fnlwgt`

# %% [markdown]
# # Extremely Randomized Trees

# %%
ert = ensemble.ExtraTreesClassifier(n_estimators = 100).fit(X_train, y_train)

err_train = np.mean(y_train != ert.predict(X_train))
err_test  = np.mean(y_test  != ert.predict(X_test))

print(err_train, err_test)
# Out:
# 4.3875043875e-05 0.182311393183

# %% [markdown]
# # AdaBoost

# %%
ada = ensemble.AdaBoostClassifier(n_estimators = 1000)
ada.fit(X_train, y_train)

err_train = np.mean(y_train != ada.predict(X_train))
err_test = np.mean(y_test != ada.predict(X_test))

print(err_train, err_test)
# Out:
# 0.159178659179 0.157948612959

# %% [markdown]
# # GBT

# %%
gbt = ensemble.GradientBoostingClassifier(n_estimators = 1000)
gbt.fit(X_train, y_train)

err_train = np.mean(y_train != gbt.predict(X_train))
err_test = np.mean(y_test != gbt.predict(X_test))

print(err_train, err_test)
# Out:
# 0.125351000351 0.156106049749
